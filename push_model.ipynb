# %%
from huggingface_hub import HfApi

api = HfApi()

local_folder_path = "data/checkpoints/weight_decay_loss/checkpoint-1365"
repo_id = "rodmosc/viral-weighted-loss"
repo_type = "model"
api.create_repo(repo_id=repo_id, repo_type=repo_type, exist_ok=True)
api.upload_folder(
    folder_path=local_folder_path,
    repo_id=repo_id,
    repo_type=repo_type,
)
print(f"Model successfully pushed to: https://huggingface.co/{repo_id}")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Model successfully pushed to: https://huggingface.co/rodmosc/viral-weighted-loss

# %%
from huggingface_hub import HfApi

api = HfApi()

local_folder_path = "data/checkpoints/experiments/focal_loss_2/checkpoint-1630"
repo_id = "rodmosc/viral-focal-loss"
repo_type = "model"
api.create_repo(repo_id=repo_id, repo_type=repo_type, exist_ok=True)
api.upload_folder(
    folder_path=local_folder_path,
    repo_id=repo_id,
    repo_type=repo_type,
)
print(f"Model successfully pushed to: https://huggingface.co/{repo_id}")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Model successfully pushed to: https://huggingface.co/rodmosc/viral-focal-loss
